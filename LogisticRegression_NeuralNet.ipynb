# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
from google.colab import files
uploaded = files.upload()

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#      <input type="file" id="files-dc61fa36-6d2b-4e2b-94be-0e3a8f689c3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc61fa36-6d2b-4e2b-94be-0e3a8f689c3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diabetes.csv to diabetes.csv
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 1s 2ms/step - loss: 0.5790 - accuracy: 0.7135
# Epoch 2/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5605 - accuracy: 0.7378
# Epoch 3/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5452 - accuracy: 0.7465
# Epoch 4/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5331 - accuracy: 0.7569
# Epoch 5/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5231 - accuracy: 0.7604
# Epoch 6/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5148 - accuracy: 0.7674
# Epoch 7/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5081 - accuracy: 0.7726
# Epoch 8/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5018 - accuracy: 0.7760
# Epoch 9/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4963 - accuracy: 0.7726
# Epoch 10/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4918 - accuracy: 0.7691
# Epoch 11/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4881 - accuracy: 0.7760
# Epoch 12/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4842 - accuracy: 0.7812
# Epoch 13/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4809 - accuracy: 0.7795
# Epoch 14/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4778 - accuracy: 0.7812
# Epoch 15/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4755 - accuracy: 0.7865
# Epoch 16/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4726 - accuracy: 0.7882
# Epoch 17/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4706 - accuracy: 0.7882
# Epoch 18/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4685 - accuracy: 0.7882
# Epoch 19/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4667 - accuracy: 0.7899
# Epoch 20/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4644 - accuracy: 0.7882
# Epoch 21/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4633 - accuracy: 0.7882
# Epoch 22/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4614 - accuracy: 0.7865
# Epoch 23/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4600 - accuracy: 0.7865
# Epoch 24/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4587 - accuracy: 0.7847
# Epoch 25/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4570 - accuracy: 0.7847
# Epoch 26/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4559 - accuracy: 0.7847
# Epoch 27/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4549 - accuracy: 0.7865
# Epoch 28/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4540 - accuracy: 0.7830
# Epoch 29/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4525 - accuracy: 0.7847
# Epoch 30/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4518 - accuracy: 0.7830
# Epoch 31/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4506 - accuracy: 0.7865
# Epoch 32/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4502 - accuracy: 0.7847
# Epoch 33/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4495 - accuracy: 0.7812
# Epoch 34/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4483 - accuracy: 0.7795
# Epoch 35/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7812
# Epoch 36/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4466 - accuracy: 0.7812
# Epoch 37/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4460 - accuracy: 0.7812
# Epoch 38/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4452 - accuracy: 0.7847
# Epoch 39/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4449 - accuracy: 0.7847
# Epoch 40/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4444 - accuracy: 0.7882
# Epoch 41/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4435 - accuracy: 0.7847
# Epoch 42/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4428 - accuracy: 0.7847
# Epoch 43/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4427 - accuracy: 0.7882
# Epoch 44/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4414 - accuracy: 0.7865
# Epoch 45/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4411 - accuracy: 0.7865
# Epoch 46/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4403 - accuracy: 0.7882
# Epoch 47/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4397 - accuracy: 0.7865
# Epoch 48/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4391 - accuracy: 0.7882
# Epoch 49/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4390 - accuracy: 0.7899
# Epoch 50/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4382 - accuracy: 0.7899
# 6/6 - 0s - loss: 0.4785 - accuracy: 0.7396 - 160ms/epoch - 27ms/step
# Loss: 0.4784754514694214, Accuracy: 0.7395833134651184
